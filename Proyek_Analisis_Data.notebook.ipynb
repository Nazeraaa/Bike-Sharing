# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Muhammad Ichsan Utama]
# - **Email:** [isan537@gmail.com]
# - **ID Dicoding:** [Muhammad Ichsan Utama]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apakah ada pola tertentu dalam jumlah penyewaan sepeda berdasarkan hari dalam seminggu??
# - Apakah ada hari tertentu dalam seminggu yang memiliki jumlah penyewaan sepeda tertinggi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#Membaca dataset
df = pd.read_csv('data/day.csv')

#Menampilkan 5 baris pertama dari dataset
df.head()

# %%
# Membaca dataset
hour_df = pd.read_csv("data/hour.csv")

# Menampilkan beberapa baris pertama dari dataset
print(hour_df.head())

# %% [markdown]
# **Insight:**
# -1. Distribusi Jumlah Penyewaan Sepeda Berdasarkan Hari dalam Seminggu:
# Dari bar plot yang menunjukkan distribusi jumlah penyewaan sepeda berdasarkan hari dalam seminggu,  apakah ada hari tertentu yang memiliki jumlah penyewaan sepeda yang lebih tinggi atau lebih rendah. Misalnya, jika hari Sabtu dan Minggu memiliki jumlah penyewaan yang lebih tinggi, ini mungkin menunjukkan bahwa lebih banyak orang menggunakan sepeda untuk rekreasi pada akhir pekan.
# - 2 . Distribusi Suhu Berdasarkan Musim:
# Dari box plot yang menunjukkan distribusi suhu berdasarkan musim, bagaimana suhu bervariasi di setiap musim. Misalnya, musim panas mungkin memiliki suhu rata-rata yang lebih tinggi dibandingkan dengan musim dingin. Ini dapat membantu \ memahami bagaimana suhu mempengaruhi jumlah penyewaan sepeda.
#
# - 3. Tren Jumlah Penyewaan Sepeda Sepanjang Waktu:
# Dari line plot yang menunjukkan tren jumlah penyewaan sepeda sepanjang waktu, melihat bagaimana jumlah penyewaan sepeda berubah dari waktu ke waktu. Misalnya,disni  mungkin melihat peningkatan jumlah penyewaan sepeda selama bulan-bulan musim panas dan penurunan selama bulan-bulan musim dingin. Ini dapat membantu kita memahami tren musiman dalam penggunaan sepeda.

# %% [markdown]
# ### Assessing Data

# %%
# Melihat struktur dari dataset
df = pd.read_csv('data/day.csv')
df.info()

# %%
# Melihat Missing Values pada dataset
df.isnull().sum()

# %%
# Melihat data yang duplikat pada dataset
df.duplicated().sum()

# %%
# Melihat Deskripsi pada dataset
df.describe()

# %%
# Mendeteksi kolom numerik (int dan float)
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Identifikasi kolom biner (hanya berisi 0 dan 1)
binary_columns = [col for col in numeric_columns if df[col].nunique() == 2]

# Hanya proses outlier pada kolom yang bukan biner
continuous_columns = [col for col in numeric_columns if col not in binary_columns]

# Visualisasi awal untuk deteksi outlier
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[continuous_columns])  # Hanya variabel kontinu
plt.title("Boxplot untuk Mendeteksi Outlier (Hanya Variabel Non-Biner)")
plt.xticks(rotation=45)
plt.show()

# Fungsi untuk mendeteksi outlier menggunakan metode IQR
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# Loop untuk menampilkan jumlah outlier per kolom
for col in continuous_columns:
    outliers = detect_outliers_iqr(df, col)
    print(f"Jumlah outlier di kolom {col}: {len(outliers)}")
    if not outliers.empty:
        print(f"Contoh outlier di {col}:\n{outliers[[col]].head()}\n")

# %%
hour_df.info()

# %%
hour_df.isna().sum()

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())

# %%
hour_df.describe()

# %% [markdown]
# **Insight:**
# - 1. Distribusi Jumlah Penyewaan Sepeda Berdasarkan Hari dalam Seminggu:
# Dari bar plot yang menunjukkan distribusi jumlah penyewaan sepeda berdasarkan hari dalam seminggu, disini  dapat dilihat bahwa ada variasi dalam jumlah penyewaan sepeda pada hari-hari yang berbeda. Misalnya, jika hari Sabtu dan Minggu memiliki jumlah penyewaan yang lebih tinggi, ini mungkin menunjukkan bahwa lebih banyak orang menggunakan sepeda untuk rekreasi pada akhir pekan. Sebaliknya, jika hari kerja memiliki jumlah penyewaan yang lebih rendah, ini mungkin menunjukkan bahwa sepeda kurang digunakan untuk perjalanan kerja.
#
# - 2. Distribusi Suhu Berdasarkan Musim:
# Dari box plot yang menunjukkan distribusi suhu berdasarkan musim, disini dapat melihat bagaimana suhu bervariasi di setiap musim. Misalnya, musim panas mungkin memiliki suhu rata-rata yang lebih tinggi dibandingkan dengan musim dingin. Ini dapat membantu  memahami bagaimana suhu mempengaruhi jumlah penyewaan sepeda. Suhu yang lebih tinggi di musim panas mungkin mendorong lebih banyak orang untuk menyewa sepeda, sementara suhu yang lebih rendah di musim dingin mungkin mengurangi jumlah penyewaan sepeda.
#
# -3. Tren Jumlah Penyewaan Sepeda Sepanjang Waktu:
# Dari line plot yang menunjukkan tren jumlah penyewaan sepeda sepanjang waktu, dapat melihat bagaimana jumlah penyewaan sepeda berubah dari waktu ke waktu. Misalnya, disini dapat  melihat peningkatan jumlah penyewaan sepeda selama bulan-bulan musim panas dan penurunan selama bulan-bulan musim dingin.
#
# -4. Pola Penyewaan Sepeda antara Hari Kerja dan Akhir Pekan/Libur:
# Dari box plot yang menunjukkan pola penyewaan sepeda antara hari kerja dan akhir pekan/libur, dapat melihat apakah ada perbedaan signifikan dalam jumlah penyewaan sepeda pada hari kerja dibandingkan dengan akhir pekan atau hari libur. Misalnya, jika jumlah penyewaan sepeda lebih tinggi pada akhir pekan, ini mungkin menunjukkan bahwa sepeda lebih sering digunakan untuk rekreasi daripada untuk perjalanan kerja.

# %% [markdown]
# ### Cleaning Data

# %%
# Mengubah tipe data kolom 'dteday' menjadi format datetime (hanya tanggal)
datetime_columns = ["dteday"]

for column in datetime_columns:
    df[column] = pd.to_datetime(df[column]).dt.normalize()

# %%
# Mengecek kembali hasilnya dari perubahan tipe data pada dteday
df.info()

# %%
# Mendeteksi kolom numerik (int dan float)
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Identifikasi kolom biner (hanya berisi 0 dan 1)
binary_columns = [col for col in numeric_columns if df[col].nunique() == 2]

# Hanya proses penghapusan outlier pada kolom non-biner
continuous_columns = [col for col in numeric_columns if col not in binary_columns]

# Fungsi untuk menghapus outlier menggunakan metode IQR lebih ketat
def remove_outliers_iqr(df, column, multiplier=1.0):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - multiplier * IQR
    upper_bound = Q3 + multiplier * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df


# Salin dataset agar tidak merusak data asli
df_cleaned_final = df.copy()

# Hapus outlier dari setiap kolom non-biner
for col in continuous_columns:
    df_cleaned_final = remove_outliers_iqr(df_cleaned_final, col)

# Visualisasi setelah penghapusan outlier
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_cleaned_final[continuous_columns])
plt.title("Boxplot Setelah Penghapusan Outlier (Hanya Variabel Non-Biner)")
plt.xticks(rotation=45)
plt.show()

# Tampilkan jumlah data setelah penghapusan outlier
print(f"Jumlah data sebelum pembersihan: {len(df)}")
print(f"Jumlah data setelah pembersihan: {len(df_cleaned_final)}")

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

# %%
hour_df.info()

# %% [markdown]
# **Insight:**
# - 1. Mendeteksi Kolom Numerik:
# mengidentifikasi kolom-kolom dalam dataset yang memiliki tipe data numerik (integer dan float). Ini penting karena outlier biasanya ditemukan dalam data numerik.
#
# - Menghapus Outlier Menggunakan Metode IQR
# - Visualisasi Setelah Penghapusan Outlier
# -Jumlah Data Sebelum dan Sesudah Pembersihan:

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Statistik deskriptif berdasarkan musim
season_stats = df_cleaned_final.groupby("season")["cnt"].describe()
print("Statistik deskriptif jumlah penyewaan berdasarkan musim:\n", season_stats)

# Statistik deskriptif berdasarkan cuaca
weather_stats = df_cleaned_final.groupby("weathersit")["cnt"].describe()
print("\nStatistik deskriptif jumlah penyewaan berdasarkan cuaca:\n", weather_stats)

# Korelasi antara cuaca, musim, dan jumlah penyewaan sepeda
correlation_matrix = df_cleaned_final[['season', 'weathersit', 'cnt']].corr()
print("\nKorelasi antara faktor cuaca/musim dengan jumlah penyewaan:\n", correlation_matrix)

# Hitung rata-rata penyewaan sepeda pada hari kerja vs akhir pekan
avg_rental = df_cleaned_final.groupby("workingday")["cnt"].mean()
print("Rata-rata penyewaan sepeda pada hari kerja vs akhir pekan:\n", avg_rental)

# Uji t-test untuk melihat signifikansi perbedaan penyewaan sepeda
from scipy.stats import ttest_ind

workday_rentals = df_cleaned_final[df_cleaned_final["workingday"] == 1]["cnt"]
weekend_rentals = df_cleaned_final[df_cleaned_final["workingday"] == 0]["cnt"]

t_stat, p_value = ttest_ind(workday_rentals, weekend_rentals, equal_var=False)
print(f"\nHasil uji t-test: t-statistic = {t_stat}, p-value = {p_value}")

# %%
hour_df.describe(include='all')

# %%
# Membaca dataset
hour_df = pd.read_csv("data/hour.csv")

# Menampilkan beberapa baris pertama dari dataset
print(hour_df.head())

# Mengelompokkan data berdasarkan kolom 'season' dan menghitung agregat
result = hour_df.groupby(by="season").agg({
    "dteday": "nunique",  # Menghitung jumlah hari unik dalam setiap musim
    "cnt": ["max", "min", "mean", "std"]  # Menghitung nilai maksimum, minimum, rata-rata, dan standar deviasi dari jumlah penyewaan sepeda dalam setiap musim
})

# Menampilkan hasil agregat
print(result)

# %%
hour_df.groupby(by="weathersit").agg({
    "dteday": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})

# %%
hour_df.groupby(by="hr").agg({
    "dteday": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})

# %% [markdown]
# **Insight:**
# - Statistik Deskriptif Berdasarkan Musim
# - cuaca cerah mungkin memiliki rata-rata penyewaan yang lebih tinggi dibandingkan dengan cuaca hujan atau berawan.
# - Korelasi Antara Cuaca, Musim, dan Jumlah Penyewaan Sepeda
# - Rata-rata Penyewaan Sepeda pada Hari Kerja vs Akhir Pekan
# - Hasil Uji T-Test perbedaan rata-rata penyewaan sepeda antara hari kerja dan akhir pekan signifikan secara statistik. Nilai p-value yang sangat kecil (biasanya kurang dari 0.05) menunjukkan bahwa perbedaan tersebut signifikan.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Membaca dataset
df = pd.read_csv('data/day.csv')

# Memeriksa nama kolom dalam dataset
print("Nama kolom dalam dataset:", df.columns)

# Memeriksa beberapa baris pertama dari dataset
print("Beberapa baris pertama dari dataset:")
print(df.head())

# Contoh analisis menggunakan kolom yang ada dalam dataset
# Misalnya, kita akan membuat bar plot distribusi jumlah penyewaan sepeda berdasarkan hari dalam seminggu
if 'weekday' in df.columns and 'cnt' in df.columns:
    plt.figure(figsize=(12, 8))
    sns.barplot(data=df, x='weekday', y='cnt', palette='viridis')
    plt.title('Distribusi Jumlah Penyewaan Sepeda Berdasarkan Hari dalam Seminggu')
    plt.xlabel('Hari dalam Seminggu')
    plt.ylabel('Jumlah Penyewaan Sepeda')
    plt.show()
else:
    print("Kolom 'weekday' atau 'cnt' tidak ditemukan dalam dataset.")

# %% [markdown]
# **Insight:**
# - Berdasarkan analisis dan visualisasi data melalui bar plot, terlihat adanya pola tertentu dalam jumlah penyewaan sepeda setiap harinya. Sebagai contoh, apabila penyewaan sepeda cenderung lebih banyak terjadi pada hari Sabtu dan Minggu, hal ini mengindikasikan bahwa sepeda lebih banyak digunakan untuk kegiatan rekreasi pada akhir pekan. Sebaliknya, jika penyewaan sepeda lebih sedikit pada hari kerja, ini menunjukkan bahwa sepeda jarang digunakan untuk perjalanan kerja.

# %% [markdown]
# ### Pertanyaan 2:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Membaca dataset
df = pd.read_csv('data/day.csv')

# Memeriksa nama kolom dalam dataset
print("Nama kolom dalam dataset:", df.columns)

# Memeriksa beberapa baris pertama dari dataset
print("Beberapa baris pertama dari dataset:")
print(df.head())

# Bar Plot: Distribusi jumlah penyewaan sepeda berdasarkan hari dalam seminggu
if 'weekday' in df.columns and 'cnt' in df.columns:
    plt.figure(figsize=(12, 8))
    sns.barplot(data=df, x='weekday', y='cnt', palette='viridis')
    plt.title('Distribusi Jumlah Penyewaan Sepeda Berdasarkan Hari dalam Seminggu')
    plt.xlabel('Hari dalam Seminggu')
    plt.ylabel('Jumlah Penyewaan Sepeda')
    plt.show()
else:
    print("Kolom 'weekday' atau 'cnt' tidak ditemukan dalam dataset.")

# Box Plot: Distribusi suhu berdasarkan musim
if 'season' in df.columns and 'temp' in df.columns:
    plt.figure(figsize=(12, 8))
    sns.boxplot(data=df, x='season', y='temp', palette='viridis')
    plt.xlabel('Musim')
    plt.ylabel('Suhu')
    plt.show()
else:
    print("Kolom 'season' atau 'temp' tidak ditemukan dalam dataset.")

# Line Plot: Tren jumlah penyewaan sepeda sepanjang waktu
if 'dteday' in df.columns and 'cnt' in df.columns:
    df['dteday'] = pd.to_datetime(df['dteday'])
    plt.figure(figsize=(12, 8))
    sns.lineplot(data=df, x='dteday', y='cnt', palette='viridis')
    plt.title('Tren Jumlah Penyewaan Sepeda Sepanjang Waktu')
    plt.xlabel('Tanggal')
    plt.ylabel('Jumlah Penyewaan Sepeda')
    plt.show()
else:
    print("Kolom 'dteday' atau 'cnt' tidak ditemukan dalam dataset.")

# %% [markdown]
# **Insight:**
# - bar plot yang menggambarkan distribusi jumlah penyewaan sepeda menurut hari dalam seminggu, kita dapat mengidentifikasi hari-hari tertentu dengan jumlah penyewaan tertinggi. Contohnya, jika data menunjukkan bahwa hari Sabtu memiliki penyewaan sepeda terbanyak, ini mengindikasikan bahwa lebih banyak orang menggunakan sepeda untuk kegiatan rekreasi pada hari tersebut. Sebaliknya, jika hari Senin mencatatkan jumlah penyewaan sepeda terendah, ini menunjukkan bahwa sepeda jarang digunakan untuk perjalanan kerja pada hari itu.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
